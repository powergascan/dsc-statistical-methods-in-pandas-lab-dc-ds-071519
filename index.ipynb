# %% [markdown]
# # Statistical Methods in Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lesson you'll get some hands-on experience using some of the key summary statistics methods in Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
#
#
# ## Getting Started
#
# For this lab, we'll be working with a dataset containing information on various lego datasets.  You will find this dataset in the file `lego_sets.csv`.
#
# In the cell below:
#
# * Import pandas and set the standard alias of `pd`
# * Load in the `lego_sets.csv` dataset using the `read_csv()` function
# * Display the head of the DataFrame to get a feel for what we'll be working with

# %%
# !pwd
# !dir
import pandas as pd
# Out:
# /home/celebrated-node-2422/dsc-statistical-methods-in-pandas-lab-dc-ds-071519
# CONTRIBUTING.md  index.ipynb  lego_sets.csv  LICENSE.md  README.md

# %%
df = pd.read_csv("lego_sets.csv")

# %% [markdown]
# ## Getting DataFrame-Level Statistics
#
# We'll begin by getting some overall summary statistics on the dataset.  There are two ways we'll get this information-- `.info()` and `.describe()`.
#
# ### Using `.info()`
#
# The `.info()` method provides us metadata on the DataFrame itself.  This allows to answer questions such as:
#
# * What data type does each column contain?
# * How many rows are in my dataset?
# * How many total non-missing values does each column contain?
# * How much memory does the DataFrame take up?
#
# In the cell below, call our DataFrame's `.info()` method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# ages                 12261 non-null object
# list_price           12261 non-null float64
# num_reviews          10641 non-null float64
# piece_count          12261 non-null float64
# play_star_rating     10486 non-null float64
# prod_desc            11884 non-null object
# prod_id              12261 non-null float64
# prod_long_desc       12261 non-null object
# review_difficulty    10206 non-null object
# set_name             12261 non-null object
# star_rating          10641 non-null float64
# theme_name           12258 non-null object
# val_star_rating      10466 non-null float64
# country              12261 non-null object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Interpreting the Results
#
# Read the output above, and then answer the following questions:
#
# How many total rows are in this DataFrame?  How many columns contain numeric data? How many contain categorical data?  Identify at least 3 columns that contain missing values.
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Using `.describe()`
#
# Whereas `.info()` provides statistics about the DataFrame itself, `.describe()` returns output containing basic summary statistics about the data contained with the DataFrame.
#
# In the cell below, call the DataFrame's `.describe()` method.

# %%
df.describe().T
# Out:
#                     count          mean            std       min       25%  \
# list_price        12261.0     65.141998      91.980429    2.2724     19.99
# num_reviews       10641.0     16.826238      36.368984    1.0000      2.00
# piece_count       12261.0    493.405921     825.364580    1.0000     97.00
# play_star_rating  10486.0      4.337641       0.652051    1.0000      4.00
# prod_id           12261.0  59836.752304  163811.452336  630.0000  21034.00
# star_rating       10641.0      4.514134       0.518865    1.8000      4.30
# val_star_rating   10466.0      4.228960       0.660282    1.0000      4.00
#
#                          50%         75%         max
# list_price           36.5878     70.1922     1104.87
# num_reviews           6.0000     13.0000      367.00
# piece_count         216.0000    544.0000     7541.00
# play_star_rating      4.5000      4.8000        5.00
# prod_id           42069.0000  70922.0000  2000431.00
# star_rating           4.7000      5.0000        5.00
# val_star_rating       4.3000      4.7000        5.00

# %% [markdown]
# #### Interpreting the Results
#
# The output contains descriptive statistics corresponding to the columns.  Use these to answer the following questions:
#
# How much is the standard deviation for piece count?  How many pieces are in the largest lego set?  How many in the smallest lego set? What is the median `val_star_rating`?
#
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Getting Summary Statistics
#
# Pandas also allows us to easily compute individual summary statistics using built-in methods.  Next, we'll get some practice using these methods.
#
# In the cell below, compute the median value of the `star_rating` column.

# %%
df.star_rating.median()
# Out:
# 4.7

# %% [markdown]
# Next, get a count of the total number of values in `play_star_rating`.

# %%
df.play_star_rating.count()
# Out:
# 10486

# %% [markdown]
# Now, compute the standard deviation of the `list_price` column.

# %%
df.list_price.std()
# Out:
# 91.9804293059243

# %% [markdown]
# If we bought every single lego set in this dataset, how many pieces would we have?
#
# > **Note**: If you truly want to answer this accurately, and are up for the challenge, try and remove duplicate lego-set entries before summing the pieces. That is, many of the lego sets are listed multiple times in the dataset above, depending on the country where it is being sold and other unique parameters. If you're stuck, just practice calculating the total number of pieces in the dataset for now.

# %%
df.drop_duplicates("prod_id")['']
# Out:
#       ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0     6-12     29.9900          2.0        277.0               4.0
# 1     6-12     19.9900          2.0        168.0               4.0
# 2     6-12     12.9900         11.0         74.0               4.3
# 3      12+     99.9900         23.0       1032.0               3.6
# 4      12+     79.9900         14.0        744.0               3.2
# 5      12+     59.9900          7.0        597.0               3.7
# 6      12+     59.9900         37.0        598.0               3.7
# 7      12+     49.9900         24.0        780.0               4.4
# 8      12+     39.9900         23.0        468.0               3.6
# 9      12+     39.9900         11.0        444.0               3.6
# 10     12+     39.9900         14.0        386.0               4.1
# 11     12+     34.9900         53.0        321.0               3.2
# 12     12+     29.9900          7.0        361.0               4.2
# 13    7-12    159.9900         63.0        847.0               3.8
# 14     10+     29.9900         13.0        708.0               4.7
# 15     10+     19.9900          1.0        234.0               3.0
# 16     10+     19.9900          1.0        160.0               5.0
# 17     10+      9.9900          1.0        149.0               2.0
# 18     10+      9.9900          1.0        141.0               2.0
# 19     10+      9.9900          3.0        101.0               4.0
# 20     10+      9.9900          2.0        105.0               3.0
# 21     10+      9.9900          1.0        113.0               5.0
# 22     10+      9.9900          1.0        136.0               NaN
# 23     10+      9.9900          2.0         91.0               3.0
# 24     10+      9.9900          7.0        140.0               3.2
# 25     10+      9.9900          5.0        143.0               4.6
# 26     10+      9.9900          3.0        122.0               2.7
# 27     10+      9.9900          5.0        130.0               4.3
# 28     10+      9.9900          3.0        119.0               4.5
# 29     10+      9.9900          1.0        135.0               1.0
# ...    ...         ...          ...          ...               ...
# 781   6-12     14.9900          7.0        141.0               4.0
# 782   6-12     14.9900         18.0        124.0               4.5
# 783     7+     16.9900         19.0         61.0               2.1
# 785   9-14     79.9900         15.0        775.0               4.8
# 786   8-14     69.9900         10.0        460.0               4.3
# 787   9-14     59.9900          6.0        564.0               4.7
# 788   8-14     34.9900         13.0        448.0               3.9
# 790   7-14     19.9900         27.0        139.0               4.2
# 898   4-99     45.5924          2.0        900.0               3.5
# 900   4-99     30.3924          2.0        502.0               5.0
# 902   4-99     30.3924          NaN        442.0               NaN
# 914   9-14     91.1924         23.0        792.0               4.7
# 947    12+     83.5924        142.0        898.0               3.9
# 969   7-14     37.9620          7.0        115.0               4.4
# 970   7-14     37.9620          4.0        102.0               4.8
# 971   7-14     30.3620          4.0        119.0               5.0
# 972   7-14     30.3620          3.0         96.0               5.0
# 978   7-14     18.9620          1.0         57.0               5.0
# 980   7-14     18.9620          3.0         73.0               3.7
# 981   7-14     18.9620          2.0         58.0               4.5
# 982   7-14     18.9620          2.0         52.0               3.5
# 984   7-14     18.9620          3.0         55.0               4.0
# 1020   2-5     45.5924          NaN        120.0               NaN
# 1026  1½-3     30.3924          NaN         80.0               NaN
# 1179    8+     26.6000         13.0          1.0               3.8
# 1238   14+    227.9924         61.0       2028.0               4.6
# 1285  8-14     60.7924         24.0        358.0               4.7
# 1554  7-14     18.2878          8.0         45.0               3.6
# 1557  7-14     36.5878         13.0         85.0               4.1
# 1559  7-14     18.2878          7.0         38.0               4.1
#
#                                               prod_desc   prod_id  \
# 0     Catapult into action and take back the eggs fr...   75823.0
# 1     Launch a flying attack and rescue the eggs fro...   75822.0
# 2     Chase the piggy with lightning-fast Chuck and ...   75821.0
# 3     Explore the architecture of the United States ...   21030.0
# 4     Recreate the Solomon R. Guggenheim Museum® wit...   21035.0
# 5     Celebrate Shanghai with this LEGO® Architectur...   21039.0
# 6     Celebrate New York City with this LEGO® Archit...   21028.0
# 7     Recreate Buckingham Palace with LEGO® Architec...   21029.0
# 8     Celebrate London with this LEGO® Architecture ...   21034.0
# 9     Celebrate Chicago with this LEGO® Architecture...   21033.0
# 10      Experience the grandeur of the Arc de Triomphe!   21036.0
# 11    Build your own LEGO® interpretation of the ico...   21019.0
# 12    Celebrate Sydney with this LEGO® Architecture ...   21032.0
# 13                  Bring your LEGO® creations to life!   17101.0
# 14        Build a LEGO® BrickHeadz version of yourself!   41597.0
# 15    Train a raptor with LEGO® BrickHeadz™ Owen and...   41614.0
# 16    Join Mr. Incredible and Frozone for LEGO® Bric...   41613.0
# 17    Growl like a Wookiee with a LEGO® BrickHeadz™ ...   41609.0
# 18    Be a rogue with a LEGO® BrickHeadz™ constructi...   41608.0
# 19    Save the universe with LEGO® BrickHeadz Iron M...   41604.0
# 20    Feel the power of Infinity with LEGO® BrickHea...   41605.0
# 21    Be a legendary outlaw with LEGO® BrickHeadz St...   41606.0
# 22    Master the skills of a green-skinned assassin ...   41607.0
# 23    Join the Resistance with a LEGO® BrickHeadz co...   41485.0
# 24    Say “I love you” with a LEGO® BrickHeadz™ Vale...   40270.0
# 25      Stand tall with LEGO® BrickHeadz Wonder Woman™!   41599.0
# 26    Live life in the fast lane with LEGO® BrickHea...   41598.0
# 27    Summon the dark side with a LEGO® BrickHeadz c...   41603.0
# 28    Feel the Force with a LEGO® BrickHeadz constru...   41602.0
# 29              Dive in with LEGO® BrickHeadz Aquaman™!   41600.0
# ...                                                 ...       ...
# 781   Power into the sky to stop Scarecrow’s fear ga...   70913.0
# 782              Help Batman™ stop The Joker™ escaping!   70900.0
# 783         Display THE LEGO® BATMAN MOVIE minifigures!  853638.0
# 785         Save the day with Batman™ and The Scuttler!   70908.0
# 786   Speed after Killer Croc’s Tail-Gator on Batman...   70907.0
# 787   Don’t get on the wrong side of the Two-Face™ E...   70915.0
# 788     Duel against the mighty Clayface™ with Batman™!   70904.0
# 790          Stop Catwoman™ escaping with the diamonds!   70902.0
# 898       Imagine and create with LEGO® Classic bricks!   10704.0
# 900        Create your ideas with LEGO® Classic bricks!   10703.0
# 902     Create a world in motion with Bricks on a Roll!   10715.0
# 914   Head for sunnier climes with the Vacation Geta...   31052.0
# 947   Enjoy the holiday season with the Winter Toy S...   10249.0
# 969   Fight ghosts with the LEGO® DIMENSIONS™ The Gh...   71228.0
# 970   Help Finn battle foes through an Adventure Tim...   71245.0
# 971   Bring the Wizarding World to life with Harry a...   71247.0
# 972   Explore the Land of Ooo with Jake and Lumpy Sp...   71246.0
# 978   Fight crime in the night with the bold and bra...   71344.0
# 980   Conquer the bad guys with action hero B.A. Bar...   71251.0
# 981         Become one with Spinjitzu Master Sensei Wu!   71234.0
# 982   Dig your way through the multiverse as DC Comi...   71240.0
# 984   Carry on your crime-fighting adventure with Mi...   71286.0
# 1020  Imagine and create with this big box of colorf...   10854.0
# 1026  Develop creativity and building skills with a ...   10848.0
# 1179                            Your robot's "fingers!"    9843.0
# 1238  Join the Ninja at the beautiful Temple of Airj...   70751.0
# 1285                     Prepare the A-wing for action!   75175.0
# 1554  Perfect your Spinjitzu skills with LEGO® NINJA...   71217.0
# 1557  Puzzle through LEGO® DIMENSIONS™ Portal® 2 wit...   71203.0
# 1559  Unleash magical powers with the Wicked Witch™ ...   71221.0
#
#                                          prod_long_desc review_difficulty  \
# 0     Use the staircase catapult to launch Red into ...           Average
# 1     Pilot Pig has taken off from Bird Island with ...              Easy
# 2     Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3     Discover the architectural secrets of the icon...           Average
# 4     Discover the architectural secrets of Frank Ll...       Challenging
# 5     Recreate Shanghai in China's blend of historic...           Average
# 6     Celebrate the architectural diversity of New Y...           Average
# 7     Build a LEGO® brick model of London's official...           Average
# 8     Celebrate the architectural diversity of Londo...           Average
# 9     Recreate Chicago’s blend of historical and mod...           Average
# 10    Capture the architectural elegance of one of t...           Average
# 11    Presenting the LEGO® Architecture interpretati...           Average
# 12    Capture the architectural essence and splendor...              Easy
# 13    Take your LEGO® play to the next level with th...           Average
# 14    Fuel your creativity by making a LEGO® BrickHe...           Average
# 15    These LEGO® BrickHeadz™ 41614 Owen & Blue cons...              Easy
# 16    These LEGO® BrickHeadz™ 41613 Mr. Incredible &...         Very Easy
# 17    This LEGO® BrickHeadz™ 41609 Chewbacca is fun ...         Very Easy
# 18    This LEGO® BrickHeadz™ 41608 Han Solo is fun t...         Very Easy
# 19    This Iron Man MK50 LEGO® BrickHeadz constructi...           Average
# 20    This Thanos LEGO® BrickHeadz construction char...              Easy
# 21    This Star-Lord LEGO® BrickHeadz construction c...              Easy
# 22    This Gamora LEGO® BrickHeadz construction char...               NaN
# 23    This LEGO® BrickHeadz construction character f...              Easy
# 24    Build your way to someone’s heart and say “Bee...              Easy
# 25    This Wonder Woman™ LEGO® BrickHeadz constructi...              Easy
# 26    The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 27    This LEGO® BrickHeadz construction character f...              Easy
# 28    This LEGO® BrickHeadz construction character f...              Easy
# 29    This Aquaman™ LEGO® BrickHeadz construction ch...         Very Easy
# ...                                                 ...               ...
# 781   Team up with Batman™ to stop Scarecrow™ spread...              Easy
# 782   Stage a face-off between The Joker™ and Batman...              Easy
# 783   Show off up to 20 THE LEGO® BATMAN MOVIE minif...         Very Easy
# 785   Ride The Scuttler with Batman™ to rescue hosta...           Average
# 786   Stage a land-water pursuit of Killer Croc’s Ta...              Easy
# 787   Stop the mighty Two-Face™ Excavator with Batma...           Average
# 788   Team up with Batman™ to take on Clayface™ and ...           Average
# 790   Help Batgirl™ and Robin™ thwart a jewel heist ...              Easy
# 898   Unleash a world of open-ended creativity and i...               NaN
# 900   Unleash a world of open-ended creativity and i...           Average
# 902   Put your LEGO® creations on wheels with this e...               NaN
# 914   Explore exciting destinations with this awesom...           Average
# 947   Welcome to the Winter Toy Shop! The holiday se...           Average
# 969   Spookify your LEGO® DIMENSIONS™ experience wit...              Easy
# 970   Enjoy more LEGO® DIMENSIONS™ gameplay with the...         Very Easy
# 971   Enhance your LEGO® DIMENSIONS™ experience with...              Easy
# 972   Enhance your LEGO® DIMENSIONS™ experience with...              Easy
# 978   Join Excalibur Batman™ from THE LEGO® BATMAN M...           Average
# 980   Enhance your LEGO® DIMENSIONS™ experience with...              Easy
# 981   Bolster your LEGO® DIMENSIONS™ gameplay with t...              Easy
# 982   Broaden your LEGO® DIMENSIONS™ gameplay with t...              Easy
# 984   Help save the LEGO® DIMENSIONS™ multiverse wit...              Easy
# 1020  Open up a world of creativity with this huge s...               NaN
# 1026  Fire your toddler’s imagination with this grea...               NaN
# 1179  The Touch Sensor reacts to touch and release, ...         Very Easy
# 1238  Enjoy the ultimate LEGO® NINJAGO™ building exp...       Challenging
# 1285  Launch into LEGO® Star Wars missions with the ...              Easy
# 1554  Bolster your LEGO® DIMENSIONS™ gameplay with t...              Easy
# 1557  Take your LEGO® DIMENSIONS™ gameplay to the ne...           Average
# 1559  Add a touch of magic to your LEGO® DIMENSIONS™...              Easy
#
#                                                set_name  star_rating  \
# 0                                 Bird Island Egg Heist          4.5
# 1                                    Piggy Plane Attack          5.0
# 2                                      Piggy Car Escape          4.3
# 3                        United States Capitol Building          4.6
# 4                         Solomon R. Guggenheim Museum®          4.6
# 5                                              Shanghai          4.9
# 6                                         New York City          4.2
# 7                                     Buckingham Palace          4.7
# 8                                                London          4.7
# 9                                               Chicago          4.8
# 10                                      Arc de Triomphe          4.4
# 11                                     The Eiffel Tower          4.6
# 12                                               Sydney          4.6
# 13                               BOOST Creative Toolbox          3.4
# 14                                          Go Brick Me          4.8
# 15                                          Owen & Blue          5.0
# 16                             Mr. Incredible & Frozone          5.0
# 17                                           Chewbacca™          3.0
# 18                                            Han Solo™          4.0
# 19                                        Iron Man MK50          4.7
# 20                                               Thanos          5.0
# 21                                            Star-Lord          5.0
# 22                                               Gamora          5.0
# 23                                                 Finn          4.5
# 24                                      Valentine's Bee          4.9
# 25                                        Wonder Woman™          5.0
# 26                                           The Flash™          4.0
# 27                                            Kylo Ren™          5.0
# 28                                                  Rey          5.0
# 29                                             Aquaman™          4.0
# ...                                                 ...          ...
# 781                         Scarecrow™ Fearful Face-off          4.1
# 782                           The Joker™ Balloon Escape          4.7
# 783   THE LEGO® BATMAN MOVIE Batman™ Minifigure Coll...          2.9
# 785                                        The Scuttler          4.7
# 786                             Killer Croc™ Tail-Gator          3.8
# 787                         Two-Face™ Double Demolition          4.8
# 788                              Clayface™ Splat Attack          4.4
# 790                            Catwoman™ Catcycle Chase          4.5
# 898                                        Creative Box          4.5
# 900                                Creative Builder Box          4.0
# 902                                    Bricks on a Roll          NaN
# 914                                   Vacation Getaways          4.9
# 947                                     Winter Toy Shop          3.8
# 969                        The Ghostbusters™ Level Pack          4.7
# 970                          Adventure Time™ Level Pack          4.5
# 971                             Harry Potter™ Team Pack          5.0
# 972                           Adventure Time™ Team Pack          4.7
# 978                          Excalibur Batman™ Fun Pack          5.0
# 980                                    A-Team™ Fun Pack          4.3
# 981                                  Sensei Wu Fun Pack          4.5
# 982                                      Bane™ Fun Pack          4.0
# 984                              Knight Rider™ Fun Pack          4.0
# 1020                          LEGO® DUPLO® Creative Box          NaN
# 1026                                    My First Bricks          NaN
# 1179                                       Touch Sensor          3.8
# 1238                                 Temple of Airjitzu          4.8
# 1285                                A-Wing Starfighter™          4.6
# 1554                                      Zane Fun Pack          4.0
# 1557                               Portal® 2 Level Pack          4.1
# 1559                             Wicked Witch™ Fun Pack          4.3
#
#                   theme_name  val_star_rating country
# 0               Angry Birds™              4.0      US
# 1               Angry Birds™              4.0      US
# 2               Angry Birds™              4.1      US
# 3               Architecture              4.3      US
# 4               Architecture              4.1      US
# 5               Architecture              4.4      US
# 6               Architecture              4.1      US
# 7               Architecture              4.3      US
# 8               Architecture              4.1      US
# 9               Architecture              4.5      US
# 10              Architecture              3.6      US
# 11              Architecture              4.4      US
# 12              Architecture              4.2      US
# 13                     BOOST              3.5      US
# 14                BrickHeadz              4.8      US
# 15                BrickHeadz              5.0      US
# 16                BrickHeadz              5.0      US
# 17                BrickHeadz              4.0      US
# 18                BrickHeadz              4.0      US
# 19                BrickHeadz              4.5      US
# 20                BrickHeadz              5.0      US
# 21                BrickHeadz              5.0      US
# 22                BrickHeadz              NaN      US
# 23                BrickHeadz              4.0      US
# 24                BrickHeadz              4.7      US
# 25                BrickHeadz              5.0      US
# 26                BrickHeadz              3.0      US
# 27                BrickHeadz              4.8      US
# 28                BrickHeadz              4.5      US
# 29                BrickHeadz              3.0      US
# ...                      ...              ...     ...
# 781   THE LEGO® BATMAN MOVIE              4.4      US
# 782   THE LEGO® BATMAN MOVIE              4.6      US
# 783   THE LEGO® BATMAN MOVIE              2.8      US
# 785   THE LEGO® BATMAN MOVIE              4.0      US
# 786   THE LEGO® BATMAN MOVIE              2.7      US
# 787   THE LEGO® BATMAN MOVIE              4.8      US
# 788   THE LEGO® BATMAN MOVIE              4.1      US
# 790   THE LEGO® BATMAN MOVIE              4.2      US
# 898                  Classic              4.5      AU
# 900                  Classic              4.0      AU
# 902                  Classic              NaN      AU
# 914           Creator 3-in-1              4.3      AU
# 947           Creator Expert              3.7      AU
# 969              DIMENSIONS™              4.3      AU
# 970              DIMENSIONS™              4.0      AU
# 971              DIMENSIONS™              4.3      AU
# 972              DIMENSIONS™              4.0      AU
# 978              DIMENSIONS™              5.0      AU
# 980              DIMENSIONS™              4.0      AU
# 981              DIMENSIONS™              4.0      AU
# 982              DIMENSIONS™              3.5      AU
# 984              DIMENSIONS™              3.7      AU
# 1020                  DUPLO®              NaN      AU
# 1026                  DUPLO®              NaN      AU
# 1179             MINDSTORMS®              3.5      AU
# 1238                NINJAGO®              4.3      AU
# 1285              Star Wars™              3.7      AU
# 1554             DIMENSIONS™              3.5      AT
# 1557             DIMENSIONS™              3.9      AT
# 1559             DIMENSIONS™              3.7      AT
#
# [744 rows x 14 columns]

# %% [markdown]
# Now, let's try getting the value for the 90% quantile.  Do this in the cell below.

# %% [markdown]
# ## Getting Summary Statistics on Categorical Data
#
# For obvious reasons, most of the methods we've used so far only work with numerical data--there's no way to calculate the standard deviation of a column containing string values. However, there are some things that we can discover about columns containing categorical data.
#
# In the cell below, get the `.unique()` values contained within the `review_difficulty` column.

# %% [markdown]
# Now, let's get the `value_counts` for this column, to see how common each is.

# %% [markdown]
# As you can see, these provide us quick and easy ways to get information on columns containing categorical information.
#
#
# ## Using `.applymap()`
#
# When working with pandas DataFrames, we can quickly compute functions on the data contained by using the `applymap()` function and passing in a lambda function.
#
# For instance, we can use `applymap()` to return a version of the DataFrame where every value has been converted to a string.
#
# In the cell below:
#
# * Call our DataFrame's `.applymap()` function and pass in `lambda x: str(x)`
# * Call our new `string_df` object's `.info()` method to confirm that everything has been cast to a string

# %%
string_df = None

# %% [markdown]
# Note that everything--even the `NaN` values, has been cast to a string in the example above.
#
# Note that for pandas Series objects (such as a single column in a DataFrame), we can do the same thing using the `apply()` method.
#
# This is just one example of how we can quickly compute custom functions on our DataFrame--this will become especially useful when we learn how to **_normalize_** our datasets in a later section!
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
